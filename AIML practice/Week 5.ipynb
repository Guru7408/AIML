# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Guru Kiran/Downloads/titanic.csv")
df1= pd.read_csv("C:/Users/Guru Kiran/Downloads/titanic.csv")
df2= pd.read_csv("C:/Users/Guru Kiran/Downloads/titanic.csv")
df3= pd.read_csv("C:/Users/Guru Kiran/Downloads/titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # 1 Detecting missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 2 Handling Missing Values

# %%
df1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # 2.1 Drop Null Values

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # 2.2 Add & Drop Attributes with Null Values

# %% [markdown]
# # Creating a fack column

# %%
df2['newfare'] = df['fare'] + 10
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ## Now i drop the column

# %%
df2.drop('newfare',axis=1)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 2.3 Fill with Mean Median Mode Value

# %%
df3.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
mean=df3['age'].mean()
df3['age']=df3['age'].fillna(mean)
df3.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
median = df['age'].median()
df['age'] = df['age'].fillna(median)
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
mode = df3['deck'].mode()[0]  
df3['deck'] = df3['deck'].fillna(mode)
df3.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # Detecting outliers

# %% [markdown]
# # 1. Univariate Outlier Detection

# %%
sns.boxplot(df['age'])
plt.show()

# %% [markdown]
# # 2. Bivariate Outlier Detection

# %%
plt.scatter(df['age'], df['fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Bivariate Outlier Detection")
plt.show()

# %% [markdown]
# # Handle Outliers

# %% [markdown]
# # IQR method

# %%
Q1 = df3['age'].quantile(0.25)
Q3 = df3['age'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
outliers = df3[(df3['age'] < lower) | (df3['age'] > upper)]
print("Univariate Outliers in Age:\n", outliers)
# Out:
# Univariate Outliers in Age:
#       survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.00      3      1  21.0750        S   Third
# 11          1       1  female  58.00      0      0  26.5500        S   First
# 15          1       2  female  55.00      0      0  16.0000        S  Second
# 16          0       3    male   2.00      4      1  29.1250        Q   Third
# 33          0       2    male  66.00      0      0  10.5000        S  Second
# ..        ...     ...     ...    ...    ...    ...      ...      ...     ...
# 827         1       2    male   1.00      0      2  37.0042        C  Second
# 829         1       1  female  62.00      0      0  80.0000      NaN   First
# 831         1       2    male   0.83      1      1  18.7500        S  Second
# 851         0       3    male  74.00      0      0   7.7750        S   Third
# 879         1       1  female  56.00      0      1  83.1583        C   First
#
# ...

# %%
# finding the 1st quartile
q1 = df["age"].quantile(0.25)

# finding the 3rd quartile
q3 = df['age'].quantile(0.75)

# finding the iqr region
iqr = q3-q1

# finding upper and lower whiskers
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

# %%
upper_bound
# Out:
# np.float64(54.5)

# %%
lower_bound
# Out:
# np.float64(2.5)

# %%
age_arr = df["age"]
outliers = age_arr[(age_arr <= lower_bound) | (age_arr >= upper_bound)]
print(outliers)
# Out:
# 7       2.00
# 11     58.00
# 15     55.00
# 16      2.00
# 33     66.00
#        ...
# 827     1.00
# 829    62.00
# 831     0.83
# 851    74.00
# 879    56.00
# Name: age, Length: 66, dtype: float64

# %%
plt.scatter(df['age'], df['fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Bivariate Outlier Detection")
plt.show()

# %%
upper_bound=400
lower_bound=0

# %%
upperIndex =df[df['fare']>upper_bound].index
df.drop(upperIndex,inplace=True)
lowerIndex =df[df['fare']<lower_bound].index
df.drop(lowerIndex,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     888 non-null    int64
#  1   pclass       888 non-null    int64
#  2   sex          888 non-null    object
#  3   age          888 non-null    float64
#  4   sibsp        888 non-null    int64
#  5   parch        888 non-null    int64
#  6   fare         888 non-null    float64
#  7   embarked     886 non-null    object
#  8   class        888 non-null    object
#  9   who          888 non-null    object
#  10  adult_male   888 non-null    bool
#  11  deck         201 non-null    object
#  12  embark_town  886 non-null    object
#  13  alive        888 non-null    object
#  14  alone        888 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 98.9+ KB

# %%
plt.scatter(df['age'], df['fare'])
